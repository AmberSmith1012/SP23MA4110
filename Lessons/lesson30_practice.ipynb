# %%
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
# Below are functions that will generate various aspects
# of the plots we need.
# Some of the code is beyond the scope of this course,
# therefore, do not worry if you do not completely
# understand all of the code you see here.

# Run this cell 


def resize_window(lim=3.5):
    plots.xlim(-lim, lim)
    plots.ylim(-lim, lim)
    
def draw_line(slope=0, intercept=0, x=make_array(-4, 4), color='r'):
    y = x*slope + intercept
    plots.plot(x, y, color=color)
    
def draw_vertical_line(x_position, color='black'):
    x = make_array(x_position, x_position)
    y = make_array(-4, 4)
    plots.plot(x, y, color=color)
    
def make_correlated_data(r):
    x = np.random.normal(0, 1, 1000)
    z = np.random.normal(0, 1, 1000)
    y = r*x + (np.sqrt(1-r**2))*z
    return x, y

def r_table(r):
    """
    Generate a table of 1000 x,y data points in standard units
    whose correlation is approximately equal to r
    """
    np.random.seed(8)
    x, y = make_correlated_data(r)
    return Table().with_columns('x', x, 'y', y)

# %% [markdown]
# ## Prediction lines

# %%
# Assign to `example` the result of calling the function `r_table`,
# using the input value of 0.99.
# Show the first 3 rows of the table

... 
...

# %%
# Create a scatter plot of our values from the table `example`

# The x-values should be represented along the x-axis and the 
# y-values should be represented along the y-axis

# Please do not delete the last line of the code that is already 
# provided

...
resize_window()

# %%
# Create a function called `nn_prediction_example` 
# that will take in an x-value.  

# Within the function, there is an assignment statement 
# `neighbors` that is assigned the results from using the 
# table `example` and locting where the x-values are within
# 0.25 to the left and right of the x-value
# that is taken into the function (the values between). 

# The function will return the average of the y-values of the 
# table `neighbors`

... (...):
    """
    Predicts y-value for x based on the example table, 
    using points within the specified number of standard units
    """
    ... 
    
    return

# %%
# Use the function `nn_prediction_example` to generate
# the y-values that are produced when the x-value used 
# is -0.5

...

# %%
# Assign to `example` the result from adding a column to the 
# table `example` with the label `Predicted y`.  The values 
# in this column are generated by applying the function
# `nn_prediction_example` to the `x` values of the table 
# `example`

example = ...

# %%
# Create a scatter plot of the x-values of the table
# `example`.  Do NOT specify the 2nd value as we want both 
# the y-values and Predicted y-values to plot

# Please do not change the last line of the code

...
resize_window()

# %%
# This code will create a scatter plot of x-values
# and add a blue line through our predicted y-values
# The slope of the line will be equal to 1

# Run this cell

example.scatter('x')
draw_line(slope=1, color='dodgerblue')
resize_window()

# %%
# Assign to `example` the result of calling the function
# `r_table` with an input value of 0

# Then create a scatter plot of the table `example`

# # The x-values should be represented along the x-axis and the 
# y-values should be represented along the y-axis

# Please do not delete the last line of the code that is already 
# provided

...

...

resize_window()

# %%
# Now that the table `example` is assigned a scatter plot
# that has an r equal to 0, we will once again use the function
# `nn_prediction_example` to generate a line for a scatter plot 
# with a correlation coefficient of 0

# Assign to `example` the result from adding a column to the 
# table `example` with the label `Predicted y`.  The values 
# in this column are generated by applying the function
# `nn_prediction_example` to the `x` values of the table 
# `example` (THIS TIME, r = 0)

# Then create a scatter plot of the table `example`

# # The x-values should be represented along the x-axis and the 
# y-values should be represented along the y-axis

# Please do not delete the last 2 lines of the code that is already 
# provided

example = ...

...

#draw_line(slope = 0)
resize_window()

# %%
# Assign to `example` the result of calling the function
# `r_table` with an input value of 0.5

# Then create a scatter plot of the table `example`

# # The x-values should be represented along the x-axis and the 
# y-values should be represented along the y-axis

# Please do not delete the last 2 lines of the code that is already 
# provided

example = ...

... 

resize_window()
draw_line(slope=1, intercept=0)

# %%
# Now that the table `example` is assigned a scatter plot
# that has an r equal to 0.5, we will once again use the function
# `nn_prediction_example` to generate a line for a scatter plot 
# with a correlation coefficient of 0

# Assign to `example` the result from adding a column to the 
# table `example` with the label `Predicted y`.  The values 
# in this column are generated by applying the function
# `nn_prediction_example` to the `x` values of the table 
# `example` (THIS TIME, r = 0.5)

# Then create a scatter plot of the table `example`

# # The x-values should be represented along the x-axis and the 
# y-values should be represented along the y-axis

# Please do not delete the last 3 lines of the code that is already 
# provided


example = ...

...

#draw_line(slope=1)
#draw_vertical_line(1.5)
resize_window()

# %%
# Run this cell

# What do you notice?

example.scatter('x')
draw_line(slope=1, intercept=0, color='red')
draw_line(slope=0.5, intercept=0, color='dodgerblue')
resize_window()

# %% [markdown]
# ## Linear regression: defining the line

# %%
# Create a function called `standard_units` that takes in any array
# and returns the array in standard units

# Recall, standard units are found by taking the difference between the
# data and the average of a data set, and then dividing by the 
# standard deviation of the same data set

def ...:
    "Convert any array of numbers to standard units."
    return ...

# %%
# The function below creates the correlation coefficient, r

# Run this cell

def correlation(t, x, y):
    x_su = standard_units(t.column(x))
    y_su = standard_units(t.column(y))
    return np.mean(x_su * y_su)

# %%
# Create a function called `slope` that takes in a 
# table, x-values, and y-values

# The function will return the slope of the regression line which
# is found by multiplying the correlation coefficient r by
# the standard deviation of the y-values in the table by the
# standard deviation of the x-values in the table

def :
    ...

# %%
# Create a function called `intercept` that takes in a 
# table, x-values, and y-values

# The function will return the intercept of the regression line
# which is found by subtracting the product of the slope of the 
# regression line and the average x-values FROM the average 
# y-values

def intercept(t, x, y):
    ...

# %%
# Run this cell

example = r_table(0.5)
slope(example, 'x', 'y')

# %% [markdown]
# ## Galton height data

# %%
# Run this cell 

galton = Table.read_table('data/galton.csv')

# %%
# Assign to `m` the rows in the table `galton`
# there the gender is `female`

# Then find the average of the `childHeight` for 
# the table m

m = ...
...

# %%
# Find the average of the height of the mother (`mother`) for 
# the table m

...

# %%
# Assign to `heights` a table with the columns "MidParent" and "Child"
# that shows the mid-parent height and child height, respectively, 
# based on the table `galton`
#

...
heights

# %%
# Create a function called `nn_prediction_galton` that takes the value
# of any height.
# Within the function `nn_prediction_galton` there is an assignment statement, 
# `neighbors`, that is assigned a table based on `heights` of the MidParent heights 
# that are +/- .5 from the value of the height taken into the function

# This function will return the average value of the column `Child` based on the table
# `neighbors`

def ...:
    """Return a prediction of the height of a child 
    whose parents have a midparent height of h.
    
    The prediction is the average height of the children 
    whose midparent height is in the range h plus or minus 0.5 inches.
    """
    neighbors = ...
    
    return ...

# %%
# Create a table called `heights_with_predictions` that adds the 
# column `Average neighbor prediction`
# and uses function `nn_prediction_galton` on the `MidParent` column 
# of the table `heights` by way of .apply

# Hint: To recall how to use .apply, refer to the documentation

heights_with_predictions = ...

# %%
# Analyze the code below.  What is the code doing?
# Run this cell

galton_slope = slope(heights, 'MidParent', 'Child')
galton_intercept = intercept(heights, 'MidParent', 'Child')
galton_slope, galton_intercept

# %% [markdown]
# Let's make a prediction for the height of these parents' children.

# %%
# Find all rows where the `MidParent` is 69.48, 
# based on the table `heights_with_predictions`

...

# %%
# Run this cell

heights_with_predictions = heights_with_predictions.with_column(
    'Regression Prediction', 
    galton_slope*heights.column('MidParent') + galton_intercept
)
heights_with_predictions

# %%
# Run this cell

heights_with_predictions.scatter('MidParent')
